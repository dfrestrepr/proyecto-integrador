# %%
dbutils.fs.mount(
  source = "wasbs://gapminder@pidevdata.blob.core.windows.net",
  mount_point = "/mnt/mountblob",
  extra_configs = {"fs.azure.account.key.pidevdata.blob.core.windows.net":dbutils.secrets.get(scope = "pi-keyvault-secrets", key = "pidbksblobsecret")})
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">ExecutionError</span>                            Traceback (most recent call last)
# <span class="ansi-green-fg">&lt;command-1990005137418935&gt;</span> in <span class="ansi-cyan-fg">&lt;module&gt;</span>
# <span class="ansi-green-intense-fg ansi-bold">      2</span>   source <span class="ansi-blue-fg">=</span> <span class="ansi-blue-fg">&#34;wasbs://gapminder@pidevdata.blob.core.windows.net&#34;</span><span class="ansi-blue-fg">,</span>
# ...

# %%
df= spark.read.csv("dbfs:/mnt/mountblob/data_gapminder_proc.csv")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
